# %%
import torch
import torchaudio
from torchaudio.models.decoder import ctc_decoder, download_pretrained_files
import IPython
import os
import fnmatch
import matplotlib.pyplot as plt
from torchmetrics.audio import NonIntrusiveSpeechQualityAssessment
#from speechbrain.inference.TTS import MSTacotron2
#from speechbrain.inference.vocoders import HIFIGAN

print('All imports done successfully!')
# Out:
# All imports done successfully!

# %%
# !pip install "torch == 2.3.1"
# !pip install "torchaudio == 2.3.1"
# Out:
# Collecting torch==2.3.1
#   Using cached torch-2.3.1-cp312-cp312-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: filelock in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1) (4.15.0)
# Requirement already satisfied: sympy in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1) (1.14.0)
# Requirement already satisfied: networkx in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1) (3.6.1)
# Requirement already satisfied: jinja2 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1) (3.1.6)
# Requirement already satisfied: fsspec in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1) (2026.1.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1) (12.1.105)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.3.1)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.1) (12.9.86)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from jinja2->torch==2.3.1) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from sympy->torch==2.3.1) (1.3.0)
# Using cached torch-2.3.1-cp312-cp312-manylinux1_x86_64.whl (779.1 MB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Installing collected packages: nvidia-cudnn-cu12, torch
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.1.0.70
#     Uninstalling nvidia-cudnn-cu12-9.1.0.70:
#       Successfully uninstalled nvidia-cudnn-cu12-9.1.0.70m0/2 [nvidia-cudnn-cu12]
#   Attempting uninstall: torch━━━━━━━━━━━━━━━━━━━ 0/2 [nvidia-cudnn-cu12]
#     Found existing installation: torch 2.4.190m━━━━━━━━━━━━━━━━━━━ 1/2 [torch]
#     Uninstalling torch-2.4.1:╺━━━━━━━━━━━━━━━━━━━ 1/2 [torch]
#       Successfully uninstalled torch-2.4.1m━━━━━━━━━━━━━━━━━━━ 1/2 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [torch]32m1/2 [torch]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.4.1 requires torch==2.4.1, but you have torch 2.3.1 which is incompatible.
# Successfully installed nvidia-cudnn-cu12-8.9.2.26 torch-2.3.1
# Collecting torchaudio==2.3.1
#   Using cached torchaudio-2.3.1-cp312-cp312-manylinux1_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: torch==2.3.1 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torchaudio==2.3.1) (2.3.1)
# Requirement already satisfied: filelock in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1->torchaudio==2.3.1) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1->torchaudio==2.3.1) (4.15.0)
# Requirement already satisfied: sympy in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1->torchaudio==2.3.1) (1.14.0)
# Requirement already satisfied: networkx in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1->torchaudio==2.3.1) (3.6.1)
# Requirement already satisfied: jinja2 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1->torchaudio==2.3.1) (3.1.6)
# Requirement already satisfied: fsspec in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1->torchaudio==2.3.1) (2026.1.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1->torchaudio==2.3.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1->torchaudio==2.3.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1->torchaudio==2.3.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1->torchaudio==2.3.1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1->torchaudio==2.3.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1->torchaudio==2.3.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1->torchaudio==2.3.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1->torchaudio==2.3.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1->torchaudio==2.3.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1->torchaudio==2.3.1) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from torch==2.3.1->torchaudio==2.3.1) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.1->torchaudio==2.3.1) (12.9.86)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from jinja2->torch==2.3.1->torchaudio==2.3.1) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/mirzadeh/projects/ASR-TTS-Course/.venv/lib/python3.12/site-packages (from sympy->torch==2.3.1->torchaudio==2.3.1) (1.3.0)
# Using cached torchaudio-2.3.1-cp312-cp312-manylinux1_x86_64.whl (3.4 MB)
# Installing collected packages: torchaudio
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.4.1
#     Uninstalling torchaudio-2.4.1:
#       Successfully uninstalled torchaudio-2.4.1
# Successfully installed torchaudio-2.3.1

# %%
from speechbrain.inference.TTS import MSTacotron2
from speechbrain.inference.vocoders import HIFIGAN
